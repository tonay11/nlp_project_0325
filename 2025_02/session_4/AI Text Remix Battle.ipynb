# %%
# !pip3 install pronouncing
import pronouncing
# Out:
# Collecting pronouncing
#   Downloading pronouncing-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cmudict>=0.4.0 (from pronouncing)
#   Downloading cmudict-1.0.32-py3-none-any.whl.metadata (3.6 kB)
# Collecting importlib-metadata>=5 (from cmudict>=0.4.0->pronouncing)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting importlib-resources>=5 (from cmudict>=0.4.0->pronouncing)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=5->cmudict>=0.4.0->pronouncing)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Downloading cmudict-1.0.32-py3-none-any.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.4/939.4 kB 8.4 MB/s eta 0:00:00
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Building wheels for collected packages: pronouncing
#   Building wheel for pronouncing (setup.py) ... done
#   Created wheel for pronouncing: filename=pronouncing-0.2.0-py2.py3-none-any.whl size=6234 sha256=f93ca297e8882e7fccc178736b4a466be8805322ec1a5f06c598d6a2a9c289d5
#   Stored in directory: /Users/toniayon/Library/Caches/pip/wheels/8b/81/fd/7edbf09827c7a7e2666e870b4c5c6b46c7ebd5defa399698bd
# Successfully built pronouncing
# Installing collected packages: zipp, importlib-resources, importlib-metadata, cmudict, pronouncing
# Successfully installed cmudict-1.0.32 importlib-metadata-8.6.1 importlib-resources-6.5.2 pronouncing-0.2.0 zipp-3.21.0

# %%
# Find rhyming words for a given word
word = "star"
rhymes = pronouncing.rhymes(word)
print(f"Words that rhyme with '{word}': {rhymes}")
# Out:
# Words that rhyme with 'star': ['abattoir', 'adar', 'aer', 'afar', 'ahr', 'ajar', 'algar', 'all-star', 'allar', 'almanzar', 'almodovar', 'alvare', 'amar', 'andujar', 'aquilar', 'ar', 'are', 'avelar', 'azar', 'azhar', 'baar', 'babar', 'bahr', 'bahre', 'balakumar', 'baldemar', 'baltazar', 'bar', 'bargar', 'barr', 'barre', 'bashar', 'bazaar', 'bazar', 'bejar', 'belvoir', 'bizarre', 'bizarre', 'bodnar', 'bogar', 'bognar', 'bomar', 'bondar', 'bonior', 'boyar', 'car', 'carr', 'carre', 'ceasar', 'char', 'cigar', 'cisar', 'claar', 'clar', 'cotnoir', 'cousar', 'csar', 'csaszar', 'czar', "d'ivoire", 'dakar', 'dar', 'dardar', 'darr', 'delamar', 'delebarre', 'demar', 'detar', 'dinar', 'disbar', 'dzhokhar', 'dzokhar', 'emdr', 'fahr', 'far', 'farquar', 'farr', 'farrar', 'ferrar', 'flohr', 'foobar', 'gaar', 'gahr', 'gar', 'ghafar', 'giroir', 'giscard', 'godar', 'gohr', 'gombar', 'gregoire', 'guitar', 'guizar', 'haar', 'hajjar', 'hamar', 'har', 'hekmatyar', 'hocevar', 'hr', 'hribar', 'hribar', 'huizar', 'jabar', 'jabbar', 'jaffar', 'jahr', 'jamar', 'jar', 'jiar', 'kadar', 'kahr', 'kahre', 'karr', 'kjar', 'kjar', 'klar', 'kumar', 'labar', 'lahr', 'lamar', 'lamarr', 'lamarr', 'lar', 'lebar', 'lemar', 'lemarr', 'maher', 'mahr', 'mar', 'marr', 'mawr', 'mcgarr', 'meagher', 'melgar', 'menjivar', 'minnaar', 'myanmar', 'najar', 'najjar', 'navar', 'navarre', 'nazar', 'nmr', 'npr', "o'barr", 'obar', 'obarr', 'our', 'paar', 'paccar', 'par', 'parr', 'pfarr', 'phar', 'pharr', 'pickar', 'pintar', 'pr', 'preslar', 'qasr', 'qatar', 'quarre', 'r', 'r.', 'rajkumar', 'renoir', 'revoir', 'ribar', 'robar', 'saar', 'sagar', 'saldivar', 'saldovar', 'sar', 'scar', 'schaar', 'schar', 'scharr', 'shahar', 'sharar', 'sharrar', 'sitar', 'skaar', 'sklar', 'soutar', 'spahr', 'spar', 'sphar', 'spohr', 'staar', 'starr', 'subpar', 'superstar', 'tabar', 'tar', 'tarr', 'tatar', 'tesar', 'thar', 'tokar', 'tovar', 'transtar', 'tsar', 'tsar', 'ulaanbaatar', 'ulaanbaatar', 'ussr', 'valdemar', 'victoire', 'voir', 'wor', 'wor', 'yahr', 'zachar', 'zadar', 'zagar', 'zalar', 'zaldivar', 'zarre', 'zulfikar']

# %%
# Find rhyming words for a given word
word = "cake"
rhymes = pronouncing.rhymes(word)
print(f"Words that rhyme with '{word}': {rhymes}")
# Out:
# Words that rhyme with 'cake': ['ache', 'ake', 'awake', 'bake', 'betake', 'blake', 'brake', 'break', 'dake', 'drake', 'fake', 'flake', 'forsake', 'haik', 'hake', 'jacque', 'jake', 'lake', 'make', 'mistake', 'naik', 'opaque', 'paik', 'pake', 'partake', 'plake', 'quake', 'rake', 'remake', 'retake', 'retake', 'sake', 'schake', 'schlake', 'schnake', 'schwake', 'shaik', 'shaikh', 'shake', 'shrake', 'snake', 'spake', 'stake', 'steak', 'take', 'wake', 'yake']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

texts = ["The moon is bright", "Stars shine at night"]
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

print("Word index:", tokenizer.word_index)
# Out:
# Word index: {'the': 1, 'moon': 2, 'is': 3, 'bright': 4, 'stars': 5, 'shine': 6, 'at': 7, 'night': 8}

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

texts = ["The money too much I'm dashing","Buy whatever you're thinking", "Na Wizzy music them want to dance to", "Are you gonna dance o"]
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

print("Word index:", tokenizer.word_index)
# Out:
# Word index: {'to': 1, 'dance': 2, 'the': 3, 'money': 4, 'too': 5, 'much': 6, "i'm": 7, 'dashing': 8, 'buy': 9, 'whatever': 10, "you're": 11, 'thinking': 12, 'na': 13, 'wizzy': 14, 'music': 15, 'them': 16, 'want': 17, 'are': 18, 'you': 19, 'gonna': 20, 'o': 21}

# %%
## **🤖 Step 2: RNN’s Power of Deep Learning! 🧠⚡**
#Unlike Markov, **RNN the Learner** remembers **everything** he reads and generates text that **flows like poetry**! 📜✨
#Let’s summon his **deep learning magic** and witness his wisdom! ⚡📖

#```python
from transformers import pipeline

# 🚀 Load the AI wizard (GPT-2 model)
generator = pipeline("text-generation", model="gpt2")

# 🌙 Invoke RNN magic
prompt = "Na Wizzy music them want to dance to"
rnn_generated_text = generator(prompt, max_length=50, num_return_sequences=1, )

print("\n🌀 **MY NEW LYRICS:**")
print(rnn_generated_text[0]["generated_text"] + " 🪩")
# Out:
# Device set to use mps:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 🌀 **MY NEW LYRICS:**
# Na Wizzy music them want to dance to because the music is so good, it helps us get that emotional connection that we need, is to dance to it? It definitely helps us get excited when we dance and feel like we're going to go 🪩

# %%
import random
import pronouncing

def build_markov_chain(text, order=1):
    """Build a Markov chain with rhyming capabilities 🎶"""
    words = text.split()
    markov_chain = {}

    for i in range(len(words) - order):
        key = tuple(words[i:i+order])
        next_word = words[i+order]
        if key not in markov_chain:
            markov_chain[key] = []
        markov_chain[key].append(next_word)

    return markov_chain

def generate_rhyming_markov_text(chain, length=10, seed_word=None):
    """Generate rhyming text using Markov chains + rhyming words 🎤"""
    key = random.choice(list(chain.keys())) if not seed_word else seed_word
    generated_words = list(key)

    for _ in range(length):
        if key in chain:
            possible_words = chain[key]
            rhyming_choices = [w for w in possible_words if pronouncing.rhymes(w)]
            next_word = random.choice(rhyming_choices) if rhyming_choices else random.choice(possible_words)
            generated_words.append(next_word)
            key = tuple(generated_words[-len(key):])
        else:
            break

    return ' '.join(generated_words)

# 📜 Example text with poetic vibes:
sacred_text = """
From Lagos to Dubai,
Abuja to Mozambique,
Johannesburg to Mumbai,
Na Wizzy music them want to dance to,
Are you gonna dance o?
"""

# 🏗️ Build & Generate!
markov_chain = build_markov_chain(sacred_text, order=2)
rhyming_text = generate_rhyming_markov_text(markov_chain, length=10)

print("🎶 Rhyming Markov Generated Text:")
print(rhyming_text + " ✨")
# Out:
# 🎶 Rhyming Markov Generated Text:
# you gonna dance o? ✨

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# 📜 Custom text dataset
poetry_lines = [
    "Are you gonna dance o?",
    "All of my diamonds are drippin' on him",
    "You know as e sabi girl dey do",
    "The night will fade away too soon"
]

# 🌟 Tokenize the dataset
tokenizer = Tokenizer()
tokenizer.fit_on_texts(poetry_lines)
total_words = len(tokenizer.word_index) + 1

# 📊 Convert text into training sequences
input_sequences = []
for line in poetry_lines:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        input_sequences.append(token_list[:i+1])

# 🚀 Pad sequences for consistency
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# 🎯 Define features & labels
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# 🔥 Build an LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(total_words, 8, input_length=max_sequence_length-1),
    tf.keras.layers.LSTM(32, return_sequences=True),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(total_words, activation='softmax')
])

# ⚡ Compile & Train
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=200, verbose=1)

# 🏆 Generate new poetic lines!
def generate_poetry(seed_text, next_words=10):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)
        seed_text += " " + tokenizer.index_word[predicted[0]]
    return seed_text

# 📝 Example Run
print("\n📜 AI-Generated Poetry:")
print(generate_poetry("The way", next_words=5))
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0833 - loss: 3.2956
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0833 - loss: 3.2946
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0833 - loss: 3.2937
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0833 - loss: 3.2927
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0833 - loss: 3.2917
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0833 - loss: 3.2906
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0833 - loss: 3.2895
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0833 - loss: 3.2882
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0833 - loss: 3.2870
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0833 - loss: 3.2856
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2841
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2825
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2808
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2789
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2769
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0417 - loss: 3.2748
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.0417 - loss: 3.2724
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2698
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2670
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2640
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2607
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2571
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2532
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0417 - loss: 3.2490
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0417 - loss: 3.2444
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2394
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2341
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2283
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2222
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2156
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.0417 - loss: 3.2086
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.2012
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.1934
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.1850
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.1761
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.1666
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0417 - loss: 3.1565
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0417 - loss: 3.1456
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0417 - loss: 3.1340
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0833 - loss: 3.1215
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0833 - loss: 3.1083
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1250 - loss: 3.0943
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1250 - loss: 3.0796
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 3.0642
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1250 - loss: 3.0481
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1250 - loss: 3.0314
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 3.0140
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1250 - loss: 2.9961
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 2.9776
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1250 - loss: 2.9585
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 2.9388
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1250 - loss: 2.9186
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 2.8978
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 2.8764
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 2.8545
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1250 - loss: 2.8320
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1667 - loss: 2.8090
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1667 - loss: 2.7855
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1667 - loss: 2.7615
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1667 - loss: 2.7371
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2083 - loss: 2.7123
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1667 - loss: 2.6871
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1667 - loss: 2.6615
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1667 - loss: 2.6356
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2500 - loss: 2.6092
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2917 - loss: 2.5825
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3333 - loss: 2.5555
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3333 - loss: 2.5281
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3333 - loss: 2.5007
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3333 - loss: 2.4733
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2917 - loss: 2.4462
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2917 - loss: 2.4192
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2917 - loss: 2.3925
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2500 - loss: 2.3658
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.3393
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2083 - loss: 2.3130
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.2868
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2917 - loss: 2.2609
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2500 - loss: 2.2355
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2917 - loss: 2.2107
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3333 - loss: 2.1864
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3333 - loss: 2.1625
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3333 - loss: 2.1389
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3333 - loss: 2.1158
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3750 - loss: 2.0935
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3750 - loss: 2.0694
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3750 - loss: 2.0457
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3750 - loss: 2.0240
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3333 - loss: 2.0021
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4167 - loss: 1.9796
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4167 - loss: 1.9580
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4583 - loss: 1.9377
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4583 - loss: 1.9178
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4167 - loss: 1.8970
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 1.8769
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 1.8582
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4583 - loss: 1.8403
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 1.8228
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4583 - loss: 1.8045
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 1.7864
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5833 - loss: 1.7691
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5417 - loss: 1.7529
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5833 - loss: 1.7375
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5417 - loss: 1.7219
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6250 - loss: 1.7063
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6250 - loss: 1.6901
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6667 - loss: 1.6747
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.6603
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6667 - loss: 1.6466
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.6336
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6667 - loss: 1.6200
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.6064
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6667 - loss: 1.5917
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.5778
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6667 - loss: 1.5653
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.5535
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.5422
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6667 - loss: 1.5298
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.5170
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 1.5042
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6667 - loss: 1.4927
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6667 - loss: 1.4822
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6667 - loss: 1.4715
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 1.4604
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7083 - loss: 1.4485
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 1.4372
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7083 - loss: 1.4268
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7083 - loss: 1.4167
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 1.4065
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7083 - loss: 1.3956
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7083 - loss: 1.3845
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 1.3737
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7083 - loss: 1.3635
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 1.3538
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 1.3441
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7083 - loss: 1.3345
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7500 - loss: 1.3247
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7500 - loss: 1.3152
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7500 - loss: 1.3061
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7500 - loss: 1.2972
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7500 - loss: 1.2884
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7500 - loss: 1.2795
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7500 - loss: 1.2706
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7500 - loss: 1.2615
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7500 - loss: 1.2525
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7917 - loss: 1.2436
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7917 - loss: 1.2348
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7917 - loss: 1.2263
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7917 - loss: 1.2179
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7917 - loss: 1.2097
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7917 - loss: 1.2015
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7500 - loss: 1.1936
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7917 - loss: 1.1857
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7500 - loss: 1.1781
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7500 - loss: 1.1703
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7500 - loss: 1.1629
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 1.1547
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7917 - loss: 1.1469
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7500 - loss: 1.1387
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7917 - loss: 1.1308
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8333 - loss: 1.1232
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8333 - loss: 1.1160
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8333 - loss: 1.1090
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8333 - loss: 1.1020
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8333 - loss: 1.0951
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8333 - loss: 1.0878
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8333 - loss: 1.0808
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8333 - loss: 1.0734
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 1.0662
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 1.0590
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8333 - loss: 1.0520
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8333 - loss: 1.0452
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 1.0385
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 1.0320
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 1.0256
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8333 - loss: 1.0196
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8333 - loss: 1.0140
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 1.0103
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8333 - loss: 1.0045
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8750 - loss: 1.0010
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 0.9890
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 0.9806
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 0.9759
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8333 - loss: 0.9715
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8333 - loss: 0.9662
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8333 - loss: 0.9570
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8333 - loss: 0.9507
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8333 - loss: 0.9469
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8750 - loss: 0.9408
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8333 - loss: 0.9338
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8333 - loss: 0.9268
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 0.9218
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 0.9173
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8750 - loss: 0.9108
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8333 - loss: 0.9040
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8333 - loss: 0.8981
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8750 - loss: 0.8932
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8333 - loss: 0.8882
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8750 - loss: 0.8821
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8333 - loss: 0.8760
#
# 📜 AI-Generated Poetry:
# The way you will fade o too

# %%
from transformers import pipeline
import random

# 🚀 Load AI wizard (GPT-2)
rnn_generator = pipeline("text-generation", model="gpt2")

# 🧙‍♂️ Markov Chain Generator
def generate_markov_seed(chain, length=5):
    """Generate a Markov chain text snippet to feed into GPT-2"""
    key = random.choice(list(chain.keys()))
    generated_words = list(key)

    for _ in range(length):
        if key in chain:
            next_word = random.choice(chain[key])
            generated_words.append(next_word)
            key = tuple(generated_words[-len(key):])
        else:
            break

    return ' '.join(generated_words)

# 🏗️ Build Markov Chain
sacred_text = """
Now it dies easy
When what's inside dried gradually
Sweetness was so divine to me
Gone was the one who'd care for me
Fell, would've left you gradually
Spoiled where we'd rather be
"""
markov_chain = build_markov_chain(sacred_text, order=2)

# 🔮 Generate a Markov seed & complete with RNN magic!
markov_seed = generate_markov_seed(markov_chain, length=7)
rnn_output = rnn_generator(markov_seed, max_length=50, num_return_sequences=1)

print("💡 Hybrid AI Poet Generated Text:")
print(rnn_output[0]["generated_text"] + " ✨")
# Out:
# Device set to use mps:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 💡 Hybrid AI Poet Generated Text:
# one who'd care for me Fell, would've left you after the party had end. I was going for your good behavior, but I was getting ahead of myself.
#
# So a couple of hours later, I'd had enough, or at ✨
